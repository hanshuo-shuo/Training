# %%
##   初始
import pandas as pd
import numpy as np
filepath_01=r'/Users/hanshuo/Desktop/明星4月起发布7日VV.xlsx'
A=pd.read_excel(filepath_01,sheet_name='按周粒度')

# %%
A['1_mean']=A['该周作品7天内VV']/A['14(4.1-4.3)']
A['2_mean']=A['该周作品7天内VV.1']/A['15(4.4-4.10)']
A['3_mean']=A['该周作品7天内VV.2']/A['16(4.11-4.17)']
A['4_mean']=A['该周作品7天内VV.3']/A['17(4.18-4.24)']
A['5_mean']=A['该周作品7天内VV.4']/A['18(4.25-5.1)']
A['6_mean']=A['该周作品7天内VV.5']/A['19(5.2-5.8)']
A['7_mean']=A['该周作品7天内VV.6']/A['20(5.9-5.15)']
A['8_mean']=A['该周作品7天内VV.7']/A['21(5.16-5.22)']
A['9_mean']=A['该周作品7天内VV.8']/A['22(5.23-5.29)']
A['10_mean']=A['该周作品7天内VV.9']/A['23(5.30-6.5)']
A['11_mean']=A['该周作品7天内VV.10']/A['24(6.6-6.12)']
A['12_mean']=A['该周作品7天内VV.11']/A['25(6.13-6.19)']
A['13_mean']=A['该周作品7天内VV.12']/A['26(6.20-6.26)']
A['14_mean']=A['该周作品7天内VV.13']/A['27(6.27-7.3)']
A['15_mean']=A['该周作品7天内VV.14']/A['28(7.4-7.7)']

# %%
a=A.loc[0:882,['明星名称','1_mean','2_mean','3_mean','4_mean','5_mean','6_mean','7_mean','8_mean','9_mean','10_mean','11_mean','12_mean','13_mean','14_mean','15_mean']]

# %%
### 出师表
a1=a.replace(1,np.NaN)
a1=a1.replace(np.inf,np.NaN)
a1
# Out:
#         明星名称   1_mean         2_mean   3_mean         4_mean        5_mean  \
# 0    宋晓波wave  36663.5  151403.818182  56560.8   69318.846154  52846.846154
# 1      演员童苡萱  27526.0            NaN      NaN  207470.250000  38382.066667
# 2      大王Ava      NaN            NaN      NaN            NaN    356.500000
# 3         田娃      NaN            NaN      NaN            NaN           NaN
# 4       龙斌-D      NaN            NaN     11.0            NaN           NaN
# ..       ...      ...            ...      ...            ...           ...
# 878      徐洁儿      NaN            NaN      NaN            NaN           NaN
# 879      倪虹洁      NaN            NaN      NaN            NaN           NaN
# 880      杨仕泽      NaN            NaN      NaN            NaN           NaN
# 881  小提琴手百合香      NaN            NaN      NaN            NaN           NaN
# 882      赵政豪      NaN            NaN      NaN            NaN           NaN
#
# ...

# %%
al=a1.loc[:,['明星名称','1_mean','2_mean','3_mean','4_mean','5_mean','6_mean','7_mean']]
ar=a1.loc[:,['明星名称','8_mean','9_mean','10_mean','11_mean','12_mean','13_mean','14_mean','15_mean']]
a1['aver_decrease']=al.mean(1)-ar.mean(1)
# Out:
# <ipython-input-6-9666037fd3fd>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a1['aver_decrease']=al.mean(1)-ar.mean(1)

# %%
a1
# Out:
#         明星名称   1_mean         2_mean   3_mean         4_mean        5_mean  \
# 0    宋晓波wave  36663.5  151403.818182  56560.8   69318.846154  52846.846154
# 1      演员童苡萱  27526.0            NaN      NaN  207470.250000  38382.066667
# 2      大王Ava      NaN            NaN      NaN            NaN    356.500000
# 3         田娃      NaN            NaN      NaN            NaN           NaN
# 4       龙斌-D      NaN            NaN     11.0            NaN           NaN
# ..       ...      ...            ...      ...            ...           ...
# 878      徐洁儿      NaN            NaN      NaN            NaN           NaN
# 879      倪虹洁      NaN            NaN      NaN            NaN           NaN
# 880      杨仕泽      NaN            NaN      NaN            NaN           NaN
# 881  小提琴手百合香      NaN            NaN      NaN            NaN           NaN
# 882      赵政豪      NaN            NaN      NaN            NaN           NaN
#
# ...

# %%
a_final=a1.sort_values(by='aver_decrease',ascending=False)
a_final.index=range(len(a_final))
a_final
# Out:
#             明星名称      1_mean        2_mean       3_mean        4_mean  \
# 0            鞠婧祎         NaN  2.481714e+07  23009105.75  7.359737e+06
# 1      时代少年团-宋亚轩         NaN           NaN          NaN  4.555989e+06
# 2            林更新         NaN           NaN          NaN           NaN
# 3    歌手崔忠华🦋《路中央》  20394209.0  8.235739e+06  17725952.50  2.211224e+07
# 4            王祖蓝         NaN           NaN   7455336.00           NaN
# ..           ...         ...           ...          ...           ...
# 878          徐洁儿         NaN           NaN          NaN           NaN
# 879          倪虹洁         NaN           NaN          NaN           NaN
# 880          杨仕泽         NaN           NaN          NaN           NaN
# 881      小提琴手百合香         NaN           NaN          NaN           NaN
# 882          赵政豪         NaN           NaN          NaN           NaN
#
#            5_mean        6_mean      7_mean      8_mean     9_mean  \
# ...

# %%
a_final=a_final.replace(np.NaN,0)
a_final
# Out:
#             明星名称      1_mean        2_mean       3_mean        4_mean  \
# 0            鞠婧祎         0.0  2.481714e+07  23009105.75  7.359737e+06
# 1      时代少年团-宋亚轩         0.0  0.000000e+00         0.00  4.555989e+06
# 2            林更新         0.0  0.000000e+00         0.00  0.000000e+00
# 3    歌手崔忠华🦋《路中央》  20394209.0  8.235739e+06  17725952.50  2.211224e+07
# 4            王祖蓝         0.0  0.000000e+00   7455336.00  0.000000e+00
# ..           ...         ...           ...          ...           ...
# 878          徐洁儿         0.0  0.000000e+00         0.00  0.000000e+00
# 879          倪虹洁         0.0  0.000000e+00         0.00  0.000000e+00
# 880          杨仕泽         0.0  0.000000e+00         0.00  0.000000e+00
# 881      小提琴手百合香         0.0  0.000000e+00         0.00  0.000000e+00
# 882          赵政豪         0.0  0.000000e+00         0.00  0.000000e+00
#
#            5_mean        6_mean      7_mean      8_mean     9_mean  \
# ...

# %%
sum(a_final['aver_decrease'])
# Out:
# 30293573.728739105

# %%
aplot=a_final.drop(columns = ['明星名称'])
aplot
# Out:
#          1_mean        2_mean       3_mean        4_mean        5_mean  \
# 0           0.0  2.481714e+07  23009105.75  7.359737e+06  0.000000e+00
# 1           0.0  0.000000e+00         0.00  4.555989e+06  1.262131e+07
# 2           0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
# 3    20394209.0  8.235739e+06  17725952.50  2.211224e+07  2.575953e+06
# 4           0.0  0.000000e+00   7455336.00  0.000000e+00  0.000000e+00
# ..          ...           ...          ...           ...           ...
# 878         0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
# 879         0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
# 880         0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
# 881         0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
# 882         0.0  0.000000e+00         0.00  0.000000e+00  0.000000e+00
#
#            6_mean      7_mean      8_mean     9_mean       10_mean  \
# ...

# %%
import matplotlib.pyplot as plt
aplot.iloc[0].astype(float).plot(label='鞠婧祎')
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 38816 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 31054 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 38816 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:201: RuntimeWarning: Glyph 23143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# ...

# %%
for i in range(26,31):
    aplot.iloc[i].astype(float).plot(label=a_final['明星名称'].astype(str)[i])
plt.legend()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 20309 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23478 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 21170 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 24917 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:238: RuntimeWarning: Glyph 23481 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# ...

# %%
a_final2['aver_decrease'].head(40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-63654d05280c> in <module>
# ----> 1 a_final2['aver_decrease'].head(40)
#
# NameError: name 'a_final2' is not defined

# %%
a_final2['明星名称'].head(40)
# Out:
# 0             张继科
# 1              李沁
# 2          陈佩斯父与子
# 3              杨幂
# 4              杨迪
# 5              沈腾
# 6           papi酱
# 7            迪丽热巴
# 8             宋小宝
# 9             范冰冰
# 10           演员江水
# 11            江疏影
# 12         八兩金888
# 13             黄渤
# 14      时代少年团-张真源
# 15            李宏毅
# 16        新势力卢鑫玉浩
# 17            陈浩民
# 18             孟非
# 19    创造营2021-任胤蓬
# 20       济公爷爷游本昌.
# 21          我是腾格尔
# 22            姜云升
# 23      时代少年团-马嘉祺
# 24             王凯
# 25            冯提莫
# 26             沈涛
# 27    创造营2021-高卿尘
# 28            林瑞阳
# 29            张予曦
# 30            刘芮麟
# 31             欢子
# 32             金靖
# 33         演员-闫学晶
# 34        林傲霏正在努力
# 35          浪子李天硕
# 36      时代少年团-严浩翔
# 37             平安
# 38             何军
# 39            潘美辰
# Name: 明星名称, dtype: object

# %%
plt.rcParams['font.sans-serif'] = ['Arial Unicode MS']
## 画图可以显示中文

# %%
def sortmax(data):
    """
    n:numbers that we need
    data
    """
    n1=data.shape[0]
    for i in range(n1):
        row=data.iloc[i:i+1]
        for i in range(1,len(row)):
            if row[i]!=np.NaN:
                 print (np.array([i,row[i]]))

# %%
n1=a1.shape[0]
for i in range(n1):
    print(a1.iloc[i:i+1])
# Out:
#       明星名称   1_mean         2_mean   3_mean        4_mean        5_mean  \
# 0  宋晓波wave  36663.5  151403.818182  56560.8  69318.846154  52846.846154
#
#     6_mean     7_mean        8_mean        9_mean  10_mean   11_mean  12_mean  \
# 0  95084.0  67991.125  50894.666667  27294.583333      NaN  104753.2  57442.0
#
#    13_mean       14_mean       15_mean  aver_decrease
# 0  39849.0  30534.833333  35276.666667   26260.569356
#     明星名称   1_mean  2_mean  3_mean     4_mean        5_mean        6_mean  \
# 1  演员童苡萱  27526.0     NaN     NaN  207470.25  38382.066667  6.041212e+06
#
#          7_mean         8_mean        9_mean  10_mean    11_mean  12_mean  \
# 1  7.659512e+06  470425.166667  74038.333333  36859.0  467565.25  54934.5
#
#    13_mean  14_mean   15_mean  aver_decrease
# 1  50796.0  29341.0  366026.0   2.601072e+06
#     明星名称  1_mean  2_mean  3_mean  4_mean  5_mean  6_mean  7_mean  8_mean  \
# 2  大王Ava     NaN     NaN     NaN     NaN   356.5     NaN   198.0     NaN
#
# ...

# %%
n1=a2.shape[0]
for i in range(n1):
    row=a2.iloc[i:i+1]

# %%
row=a2.iloc[0:1]
for i in range(1,len(row)):
    if row[i]!=np.NaN:

# %%
row=a2.iloc[0:1]
row[10][0]
# Out:
# nan

# %%
from pandas import Series,DataFrame

# %%
print(row[10][0]==Series([np.nan]))
# Out:
# 0    False
# dtype: bool

# %%
a2=a1.rename(columns={'明星名称':0,'1_mean':1,'2_mean':2,'3_mean':3,'4_mean':4,'5_mean':5,'6_mean':6,'7_mean':7,'8_mean':8,'9_mean':9,'10_mean':10,'11_mean':11,'12_mean':12,'13_mean':13,'14_mean':14,'15_mean':15})
a2
# Out:
#           0        1              2        3              4             5   \
# 0    宋晓波wave  36663.5  151403.818182  56560.8   69318.846154  52846.846154
# 1      演员童苡萱  27526.0            NaN      NaN  207470.250000  38382.066667
# 2      大王Ava      NaN            NaN      NaN            NaN    356.500000
# 3         田娃      NaN            NaN      NaN            NaN           NaN
# 4       龙斌-D      NaN            NaN     11.0            NaN           NaN
# ..       ...      ...            ...      ...            ...           ...
# 878      徐洁儿      NaN            NaN      NaN            NaN           NaN
# 879      倪虹洁      NaN            NaN      NaN            NaN           NaN
# 880      杨仕泽      NaN            NaN      NaN            NaN           NaN
# 881  小提琴手百合香      NaN            NaN      NaN            NaN           NaN
# 882      赵政豪      NaN            NaN      NaN            NaN           NaN
#
# ...

# %%
a2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 10
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
a_final2=a1.sort_values(by='aver_decrease',ascending=True)
a_final2.index=range(len(a_final))
a_final2
# Out:
#         明星名称     1_mean     2_mean        3_mean        4_mean     5_mean  \
# 0        张继科        NaN        NaN           NaN           NaN        NaN
# 1         李沁  4583760.0  4460803.0           NaN  6.596493e+05        NaN
# 2     陈佩斯父与子        NaN  1728157.0  1.351960e+05  2.568307e+06  8254703.5
# 3         杨幂        NaN  6072056.0  7.147486e+06           NaN        NaN
# 4         杨迪        NaN        NaN           NaN  1.663978e+06  1124116.5
# ..       ...        ...        ...           ...           ...        ...
# 878      徐洁儿        NaN        NaN           NaN           NaN        NaN
# 879      倪虹洁        NaN        NaN           NaN           NaN        NaN
# 880      杨仕泽        NaN        NaN           NaN           NaN        NaN
# 881  小提琴手百合香        NaN        NaN           NaN           NaN        NaN
# 882      赵政豪        NaN        NaN           NaN           NaN        NaN
#
#         6_mean    7_mean      8_mean     9_mean       10_mean     11_mean  \
# ...

# %%
aplot2=a_final2.drop(columns = ['明星名称'])
aplot2
# Out:
#         1_mean     2_mean        3_mean        4_mean     5_mean     6_mean  \
# 0          NaN        NaN           NaN           NaN        NaN     5700.0
# 1    4583760.0  4460803.0           NaN  6.596493e+05        NaN  2533517.0
# 2          NaN  1728157.0  1.351960e+05  2.568307e+06  8254703.5   916643.0
# 3          NaN  6072056.0  7.147486e+06           NaN        NaN        NaN
# 4          NaN        NaN           NaN  1.663978e+06  1124116.5  4873384.0
# ..         ...        ...           ...           ...        ...        ...
# 878        NaN        NaN           NaN           NaN        NaN        NaN
# 879        NaN        NaN           NaN           NaN        NaN        NaN
# 880        NaN        NaN           NaN           NaN        NaN        NaN
# 881        NaN        NaN           NaN           NaN        NaN        NaN
# 882        NaN        NaN           NaN           NaN        NaN        NaN
#
# ...

# %%
for i in range(25,30):
    aplot2.iloc[i].astype(float).plot(label=a_final2['明星名称'].astype(str)[i])
plt.legend()
plt.show()

# %%
A.iloc[884].astype(float).plot(label=A['明星名称'].astype(str)[884])
# Out:
# <AxesSubplot:>

# %%
A.iloc[884]
# Out:
# 明星ID                       NaN
# 明星名称                       NaN
# 14(4.1-4.3)                NaN
# 该周作品7天内VV          342642420.0
# 15(4.4-4.10)               NaN
# 该周作品7天内VV.1        980133329.0
# 16(4.11-4.17)              NaN
# 该周作品7天内VV.2       1101180119.0
# 17(4.18-4.24)              NaN
# 该周作品7天内VV.3        854073492.0
# 18(4.25-5.1)               NaN
# 该周作品7天内VV.4        892308083.0
# 19(5.2-5.8)                NaN
# 该周作品7天内VV.5        783014091.0
# 20(5.9-5.15)               NaN
# 该周作品7天内VV.6        695205486.0
# 21(5.16-5.22)              NaN
# 该周作品7天内VV.7        707999212.0
# 22(5.23-5.29)              NaN
# 该周作品7天内VV.8        493677366.0
# 23(5.30-6.5)               NaN
# 该周作品7天内VV.9        963656167.0
# 24(6.6-6.12)               NaN
# 该周作品7天内VV.10       768326550.0
# 25(6.13-6.19)              NaN
# 该周作品7天内VV.11       732036400.0
# 26(6.20-6.26)              NaN
# 该周作品7天内VV.12       753444426.0
# 27(6.27-7.3)               NaN
# 该周作品7天内VV.13       546955198.0
# ...

# %%
y=[342642420.0/709,980133329.0/1651,1101180119.0/2070,854073492.0/1997,892308083.0/3146,783014091.0/1532,695205486.0/1636,707999212.0/1674,493677366.0/2524,963656167.0/2221,768326550.0/1834,732036400.0/1921, 753444426.0/2167,546955198/2332, 184081838.0/783]
y1=abs(a_final2['aver_decrease']).head(400)
y2=abs(a_final['aver_decrease']).head(400)
x=range(len(y))
##plt.plot(x,y1,'',label="上升播放量")
##plt.plot(x,y2,'',label="下降播放量")
plt.plot(x,y,'',label="每条视频平均播放量")
plt.legend(loc='upper right')
##plt.xlabel('明星标签')
###plt.ylabel('周总播放量')
plt.xlabel('周数')
plt.ylabel('播放量')
plt.show()

# %%
sum(a_final2['aver_decrease'].replace(np.NaN,0))
# Out:
# 30293573.728739053

# %%
806936717.1428572-557335407.75
# Out:
# 249601309.3928572

# %%
sum([342642420.0,980133329.0,1101180119.0,854073492.0,892308083.0,783014091.0,695205486.0])/7
# Out:
# 806936717.1428572

# %%
sum([493677366.0,963656167.0,76832655,732036400.0, 753444426.0,546955198, 184081838.0,707999212.0])/8
# Out:
# 557335407.75

# %%
342642420		980133329		1101180119		854073492		892308083		783014091		695205486		707999212		493677366		963656167		768326550		732036400		753444426		546955198		184081838

# %%
sum([342642420.0/709,980133329.0/1651,1101180119.0/2070,854073492.0/1997,892308083.0/3146,783014091.0/1532,695205486.0/1636])/7
# Out:
# 465180.85371601215

# %%
sum ([707999212.0/1674,493677366.0/2524,963656167.0/2221,768326550.0/1834,732036400.0/1921, 753444426.0/2167,546955198/2332, 184081838.0/783])/8
# Out:
# 333719.09147020016

# %% [markdown]
# ## 看新增拍摄视频数

# %%
A2=A.loc[0:882,['明星名称','14(4.1-4.3)','15(4.4-4.10)','16(4.11-4.17)','17(4.18-4.24)','18(4.25-5.1)','19(5.2-5.8)','20(5.9-5.15)','21(5.16-5.22)','22(5.23-5.29)','23(5.30-6.5)','24(6.6-6.12)','25(6.13-6.19)','26(6.20-6.26)','27(6.27-7.3)','28(7.4-7.7)']]
A2
# Out:
#         明星名称  14(4.1-4.3)  15(4.4-4.10)  16(4.11-4.17)  17(4.18-4.24)  \
# 0    宋晓波wave          4.0          11.0           10.0           13.0
# 1      演员童苡萱          1.0           NaN            NaN            4.0
# 2      大王Ava          NaN           NaN            NaN            NaN
# 3         田娃          NaN           NaN            NaN            NaN
# 4       龙斌-D          NaN           NaN            2.0            NaN
# ..       ...          ...           ...            ...            ...
# 878      徐洁儿          NaN           NaN            NaN            NaN
# 879      倪虹洁          NaN           NaN            NaN            NaN
# 880      杨仕泽          NaN           NaN            NaN            NaN
# 881  小提琴手百合香          NaN           NaN            NaN            NaN
# 882      赵政豪          NaN           NaN            NaN            NaN
#
#      18(4.25-5.1)  19(5.2-5.8)  20(5.9-5.15)  21(5.16-5.22)  22(5.23-5.29)  \
# ...

# %%
a2l=A2.loc[:,['明星名称','14(4.1-4.3)','15(4.4-4.10)','16(4.11-4.17)','17(4.18-4.24)','18(4.25-5.1)','19(5.2-5.8)','20(5.9-5.15)']]
a2r=A2.loc[:,['明星名称','21(5.16-5.22)','22(5.23-5.29)','23(5.30-6.5)','24(6.6-6.12)','25(6.13-6.19)','26(6.20-6.26)','27(6.27-7.3)','28(7.4-7.7)']]

# %%
A2['aver_decrease']=a2l.mean(1)-a2r.mean(1)
# Out:
# <ipython-input-19-7c206414d51a>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   A2['aver_decrease']=a2l.mean(1)-a2r.mean(1)

# %%
A2
# Out:
#         明星名称  14(4.1-4.3)  15(4.4-4.10)  16(4.11-4.17)  17(4.18-4.24)  \
# 0    宋晓波wave          4.0          11.0           10.0           13.0
# 1      演员童苡萱          1.0           NaN            NaN            4.0
# 2      大王Ava          NaN           NaN            NaN            NaN
# 3         田娃          NaN           NaN            NaN            NaN
# 4       龙斌-D          NaN           NaN            2.0            NaN
# ..       ...          ...           ...            ...            ...
# 878      徐洁儿          NaN           NaN            NaN            NaN
# 879      倪虹洁          NaN           NaN            NaN            NaN
# 880      杨仕泽          NaN           NaN            NaN            NaN
# 881  小提琴手百合香          NaN           NaN            NaN            NaN
# 882      赵政豪          NaN           NaN            NaN            NaN
#
#      18(4.25-5.1)  19(5.2-5.8)  20(5.9-5.15)  21(5.16-5.22)  22(5.23-5.29)  \
# ...

# %%
y=[709,1651,2070,1997,3146,1532,1636,1674,2524,2221,1834,1921,2167,2332,783]
y1=abs(a_final2['aver_decrease']).head(400)
y2=abs(a_final['aver_decrease']).head(400)
x=range(len(y))
##plt.plot(x,y1,'',label="上升播放量")
##plt.plot(x,y2,'',label="下降播放量")
plt.plot(x,y,'',label="每周发布视频量")
plt.legend(loc='upper right')
##plt.xlabel('明星标签')
###plt.ylabel('周总播放量')
plt.xlabel('周数')
plt.ylabel('视频数')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-21-bf1b33b4ecbf> in <module>
#       1 y=[709,1651,2070,1997,3146,1532,1636,1674,2524,2221,1834,1921,2167,2332,783]
# ----> 2 y1=abs(a_final2['aver_decrease']).head(400)
#       3 y2=abs(a_final['aver_decrease']).head(400)
#       4 x=range(len(y))
#       5 ##plt.plot(x,y1,'',label="上升播放量")
#
# NameError: name 'a_final2' is not defined

# %%
sum([709,1651,2070,1997,3146,1532,1636])/7
# Out:
# 1820.142857142857

# %%
sum([1674,2524,2221,1834,1921,2167,2332,783])/8
# Out:
# 1932.0

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-218-c27994dde3a5> in <module>
#       1 import sys
#       2 sys.path.append('/home/public/benyuansong')
# ----> 3 from DID import did
#       4 from DID import ttest
#       5 from DID import preprocessing
#
# ModuleNotFoundError: No module named 'DID'

# %% [markdown]
# ### 创造营
# 先看平均播放量

# %%
anew=a.loc[a['明星名称'].str.contains('创造营')]

# %%
anew
# Out:
#               明星名称  1_mean      2_mean     3_mean     4_mean     5_mean  \
# 26     创造营2021-韩佩泉     NaN  4906437.75   573050.0  6287413.0  2161887.0
# 43   创造营2021-羽生田挙武     NaN   152840.00    88240.5    25361.0        NaN
# 54     创造营2021-甘望星     NaN   575260.50  1702765.0   782724.5        NaN
# 63      创造营2021-井胧     NaN   630423.00  1224994.5        NaN  7685873.5
# 74     创造营2021-陈俊洁     NaN    22181.00        NaN        NaN        NaN
# ..             ...     ...         ...        ...        ...        ...
# 753    创造营2021-付思超     NaN   149071.00   111938.0    66278.0        NaN
# 754    创造营2021-魏子越     NaN    31725.50   187032.0        NaN        NaN
# 756    创造营2021-何屹繁     NaN   178852.00    22063.0        NaN        NaN
# 758   创造营2021-井汲大翔     NaN   601240.00   367100.5   122898.0        NaN
# 761   创造营2021-上原一翔     NaN    62524.00        NaN        NaN        NaN
#
#         6_mean     7_mean     8_mean     9_mean       10_mean    11_mean  \
# ...

# %%
anew.to_excel(r'/Users/hanshuo/Desktop/创造营.xlsx')

# %%
alnew=anew.loc[:,['明星名称','1_mean','2_mean','3_mean','4_mean','5_mean','6_mean','7_mean']]
arnew=anew.loc[:,['明星名称','8_mean','9_mean','10_mean','11_mean','12_mean','13_mean','14_mean','15_mean']]

# %%
anew['aver_decrease']=alnew.mean(1)-arnew.mean(1)
# Out:
# <ipython-input-26-2837dcf6239f>:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   anew['aver_decrease']=alnew.mean(1)-arnew.mean(1)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
anew
# Out:
#               明星名称  1_mean      2_mean     3_mean     4_mean     5_mean  \
# 26     创造营2021-韩佩泉     NaN  4906437.75   573050.0  6287413.0  2161887.0
# 43   创造营2021-羽生田挙武     NaN   152840.00    88240.5    25361.0        NaN
# 54     创造营2021-甘望星     NaN   575260.50  1702765.0   782724.5        NaN
# 63      创造营2021-井胧     NaN   630423.00  1224994.5        NaN  7685873.5
# 74     创造营2021-陈俊洁     NaN    22181.00        NaN        NaN        NaN
# ..             ...     ...         ...        ...        ...        ...
# 753    创造营2021-付思超     NaN   149071.00   111938.0    66278.0        NaN
# 754    创造营2021-魏子越     NaN    31725.50   187032.0        NaN        NaN
# 756    创造营2021-何屹繁     NaN   178852.00    22063.0        NaN        NaN
# 758   创造营2021-井汲大翔     NaN   601240.00   367100.5   122898.0        NaN
# 761   创造营2021-上原一翔     NaN    62524.00        NaN        NaN        NaN
#
#         6_mean     7_mean     8_mean     9_mean       10_mean    11_mean  \
# ...

# %%
sum(anew['aver_decrease'].replace(np.NaN,0))
# Out:
# 8103037.003798185

# %%
anew2=a.loc[a['明星名称'].str.contains('少年团')]
anew2
# Out:
#           明星名称     1_mean  2_mean     3_mean     4_mean        5_mean  \
# 611   X玖少年团伍嘉成        NaN     NaN        NaN        NaN           NaN
# 614  时代少年团-马嘉祺        NaN     NaN        NaN  2829202.0  1.488048e+06
# 615  时代少年团-丁程鑫        NaN     NaN        NaN  3630759.0  9.027270e+05
# 616  时代少年团-宋亚轩        NaN     NaN        NaN  4555989.0  1.262131e+07
# 617  时代少年团-刘耀文        NaN     NaN        NaN  5817502.0  1.672200e+06
# 618  时代少年团-严浩翔        NaN     NaN        NaN  3100303.0  6.921875e+05
# 619  时代少年团-贺峻霖        NaN     NaN        NaN  3124242.0  2.311777e+06
# 620  时代少年团-张真源        NaN     NaN        NaN  3949842.0  7.666330e+05
# 621      时代少年团  6766832.0     NaN  3271949.0   127472.0           NaN
#
#          6_mean     7_mean  8_mean     9_mean    10_mean    11_mean  \
# 611         NaN        NaN     NaN        NaN        NaN     8813.0
# 614         NaN        NaN     NaN        NaN        NaN        NaN
# ...

# %%
alnew2=anew2.loc[:,['明星名称','1_mean','2_mean','3_mean','4_mean','5_mean','6_mean','7_mean']]
arnew2=anew2.loc[:,['明星名称','8_mean','9_mean','10_mean','11_mean','12_mean','13_mean','14_mean','15_mean']]
anew2['aver_decrease']=alnew2.mean(1)-arnew2.mean(1)
# Out:
# <ipython-input-36-9ea42e27c7fb>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   anew2['aver_decrease']=alnew2.mean(1)-arnew2.mean(1)
# /opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)

# %%
anew2
# Out:
#           明星名称     1_mean  2_mean     3_mean     4_mean        5_mean  \
# 611   X玖少年团伍嘉成        NaN     NaN        NaN        NaN           NaN
# 614  时代少年团-马嘉祺        NaN     NaN        NaN  2829202.0  1.488048e+06
# 615  时代少年团-丁程鑫        NaN     NaN        NaN  3630759.0  9.027270e+05
# 616  时代少年团-宋亚轩        NaN     NaN        NaN  4555989.0  1.262131e+07
# 617  时代少年团-刘耀文        NaN     NaN        NaN  5817502.0  1.672200e+06
# 618  时代少年团-严浩翔        NaN     NaN        NaN  3100303.0  6.921875e+05
# 619  时代少年团-贺峻霖        NaN     NaN        NaN  3124242.0  2.311777e+06
# 620  时代少年团-张真源        NaN     NaN        NaN  3949842.0  7.666330e+05
# 621      时代少年团  6766832.0     NaN  3271949.0   127472.0           NaN
#
#          6_mean     7_mean  8_mean     9_mean    10_mean    11_mean  \
# 611         NaN        NaN     NaN        NaN        NaN     8813.0
# 614         NaN        NaN     NaN        NaN        NaN        NaN
# ...

# %%
sum(anew2['aver_decrease'].replace(np.NaN,0))
# Out:
# 5040421.713888891

# %%
anew2.to_excel(r'/Users/hanshuo/Desktop/时代少年团.xlsx')

# %%
s=anew['明星名称']
for index in s:
    print(index)
# Out:
# 创造营2021-韩佩泉
# 创造营2021-羽生田挙武
# 创造营2021-甘望星
# 创造营2021-井胧
# 创造营2021-陈俊洁
# 创造营2021-何圳煜
# 创造营2021-张星特
# 创造营2021-刘唐辉
# 创造营2021-阿克朱力
# 创造营2021-李沛洋
# 创造营2021-张嘉元
# 创造营2021-李洛尔
# 创造营2021-郑明鑫
# 创造营2021-卢克
# 创造营2021-王孝辰
# 创造营2021-刘彰
# 创造营2021-俞更寅
# 创造营2021-诺言
# 创造营2021-林煜修
# 创造营2021-薛八一
# 创造营2021-张欣尧
# 创造营2021-门胁慎刚
# 创造营2021-吴海
# 创造营2021-肖力桓
# 创造营2021-伯远
# 创造营2021-张腾
# 创造营2021-胡烨韬
# 创造营2021-李嘉祥
# 创造营2021-谢兴阳
# 创造营2021-力丸
# 创造营2021-赞多
# 创造营2021-安迪
# 创造营2021-代少冬
# 创造营2021-曾涵江
# 创造营2021-蒋敦豪
# 创造营2021-叶皓然
# 创造营2021-尹浩宇
# 创造营2021-高卿尘
# 创造营2021-曹左
# 创造营2021-荣耀
# 创造营2021-奥斯卡
# 创造营2021-于洋
# 创造营2021-米卡
# 创造营2021-庆怜
# 创造营2021-贵尚奇
# 创造营2021-利路修
# 创造营2021-张璋
# 创造营2021-林墨
# 创造营2021-陆定昊
# 创造营2021-邵明明
# 创造营2021-吴宇恒
# 创造营2021-李政庭
# 创造营2021-屈柏宇
# 创造营2021-刘聪
# 创造营2021-大卫
# 创造营2021-黄鲲
# 创造营2021-任胤蓬
# 创造营2021-付思超
# 创造营2021-魏子越
# 创造营2021-何屹繁
# 创造营2021-井汲大翔
# 创造营2021-上原一翔

# %%
for index in s:
    a = a[a.明星名称 != index]

# %%
a=a.replace(1,np.NaN)
a=a.replace(np.inf,np.NaN)
a=a.replace(np.NaN,0)

# %%
al2=a.loc[:,['明星名称','1_mean','2_mean','3_mean','4_mean','5_mean','6_mean','7_mean']]
ar2=a.loc[:,['明星名称','8_mean','9_mean','10_mean','11_mean','12_mean','13_mean','14_mean','15_mean']]
a['aver_decrease']=al2.mean(1)-ar2.mean(1)
# Out:
# <ipython-input-43-bc045fa48bfb>:3: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   a['aver_decrease']=al2.mean(1)-ar2.mean(1)

# %%
sum(a['aver_decrease'])
# Out:
# 36677388.69288943

# %%
s2=anew2['明星名称']
for index in s2:
    print(index)
# Out:
# X玖少年团伍嘉成
# 时代少年团-马嘉祺
# 时代少年团-丁程鑫
# 时代少年团-宋亚轩
# 时代少年团-刘耀文
# 时代少年团-严浩翔
# 时代少年团-贺峻霖
# 时代少年团-张真源
# 时代少年团
